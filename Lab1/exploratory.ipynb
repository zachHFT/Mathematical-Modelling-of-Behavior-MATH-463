# %%
import pandas as pd

# %%
df = pd.read_csv('netherlands.dat', '\t')

# %%
df
# Out:
#        id  rp  sp  choice  purpose  npersons  age  employ_status  mainearn  \
# 0       1   1   0       0        0         3    0              0         0
# 1       1   0   1      10        0         3    0              0         0
# 2       1   0   1      10        0         3    0              0         0
# 3       1   0   1      10        0         3    0              0         0
# 4       1   0   1      10        0         3    0              0         0
# ...   ...  ..  ..     ...      ...       ...  ...            ...       ...
# 1734  235   0   1      10        0         4    1              1         0
# 1735  235   0   1      10        0         4    1              1         0
# 1736  235   0   1      10        0         4    1              1         0
# 1737  235   0   1      10        0         4    1              1         0
# 1738  235   0   1      10        0         4    1              1         0
#
# ...

# %%
df.describe()
# Out:
#                 id           rp           sp       choice      purpose  \
# count  1739.000000  1739.000000  1739.000000  1739.000000  1739.000000
# mean    118.836688     0.131110     0.868890     8.969523     0.161587
# std      67.139454     0.337618     0.337618     3.377086     0.368178
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%      60.000000     0.000000     1.000000    10.000000     0.000000
# 50%     122.000000     0.000000     1.000000    10.000000     0.000000
# 75%     176.000000     0.000000     1.000000    10.000000     0.000000
# max     235.000000     1.000000     1.000000    11.000000     1.000000
#
#           npersons          age  employ_status     mainearn  arrival_time  \
# count  1739.000000  1739.000000    1739.000000  1739.000000   1739.000000
# mean      2.455434     0.327200       0.489937     0.480736      0.387004
# std       1.296027     0.469326       0.500043     0.499772      0.487205
# ...

# %%
import matplotlib as plt

# %%
df['age'].plt()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-da90f0f829d7> in <module>
# ----> 1 df['age'].plt()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'plt'
